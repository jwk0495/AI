# %%
# 1. 모듈 임포트
import requests
from bs4 import BeautifulSoup

# %%
# 2. html 요소 얻기
keyword = "여의도"
url = f"https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={keyword}+날씨"
page= requests.get(url)

# %%
# 3. BeatifulSoup 으로 파싱
bs_result = BeautifulSoup(page.text, 'html.parser')
bs_result
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="여의도 날씨 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'여의도 날씨'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'여의도 날씨'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>여의도 날씨 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240228.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_240228.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_231130.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.vis ...
#     /* 토글 패널 스타일 */
#     .weather_layer_pop[aria-hidden="true"] {
#         display: none;
#     }
#     .weather_layer_pop[aria-hidden="false"] {
#         display: block;
#     }
#
#     /* 그래프 스타일 */
#     .cs_weather_new .weather_graph_box .canvas {
#         position: absolute;
#     }
#
#     .cs_weather_new .weather_graph_box .scroll_box > div {
#         position: relative;
#     }
#
#     /* 상단 오늘/내일/모레/월간 탭 노출 스타일 */
#     .content_wrap [data-kgs-tab-panel].open {
#         display: block;
#     }
#     .content_wrap [data-kgs-tab-panel] {
#         display: none;
#     }
# </style> <section class="sc_new cs_weather_new _cs_weather"> <div class="_tab_flicking" data-kgs-tab=""> <div class="api_subject_bx"> <div class="top_wrap"> <div class="title_area _area_panel"> <h2 class="blind">영등포구 여의도동</h2> <h2 class="title">영등포구 여의도동</h2> <a class="link_cctv" href="https://weather.naver.com/map/09560110?cctv=true" nocr="" onclick="return goOtherCR(this, 'a=nco_x7t*4.cctv&amp;r=1&amp;i=88157038_00000065035F&amp;u=' + urlencode(this.href));" target="_blank"><span class="text_cctv">CCTV</span></a> </div> <div class="sub_tab_area"> <div class="type_scroll"> <div> <ul class="sub_tab_list" data-kgs-selectable="" role="tablist"> <li aria-selected="true" class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">오늘</span> </a> </li> <li class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">내일</span> </a> </li> <li class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">모레</span> </a> </li> <li class="sub_tab" data-kgs-tab-toggle="" role="tab"> <a href="#" nocr="" onclick="goOtherTCR(this, 'a=nco_x7t*4&amp;r=1&amp;i=88157038_00000065035F');return false;"> <span class="menu">월간</span> </a> </li> </ul> </div> </div> </div> </div> <div class="content_wrap"> <div class="open" data-kgs-tab-panel=""> <div class="content_area"> <div class="inner"> <div class="multi_cp_area"> <h3 class="blind">날씨 제공사 설정</h3> <div class="multi_cp_info"> <span class="thumb_box"><img alt="제공사 로고" class="_logo" src="https://ssl.pstatic.net/sstatic/keypage/outside/scui/weather_new_new/img/logo_kma.png" style="width: 20px; height: 20px"/></span> <span class="text"><strong class="provider _provider">기상청</strong></span> </div> <div class="provider_select _provider_select"> <a aria-expanded="false" class="title_select _select_trigger" href="#" nocr=""> <strong class="title">제공</strong> </a> <div aria-hidden="true" class="filter_area _select_panel"> <div class="filter_option"> <div class="filter_wrap"> <div class="filter_group"> <strong class="blind">제공사</strong> <div class="filter_cont"> <ul class="list_item" data-kgs-selectable="" onchange="tCR('a=nco_x7t*4.slcparrow&amp;r=1&amp;i=88157038_00000065035F');" role="tablist"> <li aria-selected="true" class="item" data-kgs-option="weather" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>기상청</a></li> <li class="item" data-kgs-option="accuWeather" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>아큐웨더</a></li> <li class="item" data-kgs-option="twcWeather" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>웨더채널</a></li> <li class="item" data-kgs-option="weatherNews" role="tab"><a class="item_link" href="#" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));'>웨더뉴스</a></li> </ul> </div> </div> </div> </div> </div> </div> <a class="btn_comparison" href="https://weather.naver.com/compare/09560110" onclick='return goOtherCR(this,"a=nco_x7t*4&amp;r=1&amp;i="+urlencode("88157038_00000065035F")+"&amp;u="+urlencode(this.href));' role="button"><span class="text_comparison">예보비교</span></a> </div> <div class="weather_info"> <div class="status_wrap"> <h3 class="blind">오늘의 날씨</h3> <div class="_today"> <div class="weather_graphic"> <div class="weather_main"> <i class="wt_icon ico_wt7"><span class="blind">흐림</span></i>  ...
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_02_28_42/b1cf4bef-d634-11ee-ac2a-e4434b2a1c7c.mp4?__gda__=1709155731_5e9f70dd2a5c008c34e2438c69fcddb4" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span class="api_badge_video"><i class="spnew ico_thumbnail"></i>주요장면 5개</span>
# <span aria-label="재생시간 01:26" class="time">01:26</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*K.close&amp;r=1&amp;i=2550431020_8815b1c9_000047675637&amp;g="+urlencode("1:1:0:1111|8815b1c9_000047675637:0|0:0:0:1:1")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*K.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kep&amp;r=&amp;i=" data-url="https://tv.naver.com/v/47675637" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*K.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*K.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="https://tv.naver.com/v/47675637" onclick='return goOtherCR(this,"a=vdo_lst*K.tit&amp;r=1&amp;i=2550431020_8815b1c9_000047675637&amp;g="+urlencode("1:1:0:1111|8815b1c9_000047675637:0|0:0:0:1:1")+"&amp;u="+urlencode(this.href))' target="_blank">[<mark>날씨</mark>] 내일 충청 이남 눈, 비…그치고 반짝 꽃샘추위</a><div class="info_sub"><div class="desc_group"><a class="channel" href="https://tv.naver.com/yonhapnewstv" onclick='return goOtherCR(this,"a=vdo_lst*K.cha&amp;r=1&amp;i=2550431020_8815b1c9_000047675637&amp;g="+urlencode("1:1:0:1111|8815b1c9_000047675637:0|0:0:0:1:1")+"&amp;u="+urlencode(this.href))' target="_blank">연합뉴스TV</a><a class="ico_official_area" href="#"><i class="spnew api_ico_official2">공식</i> <span class="tooltip">공식</span></a></div><div class="desc_group"><a class="origin" href="https://tv.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*K.sou&amp;r=1&amp;i=2550431020_8815b1c9_000047675637&amp;g="+urlencode("1:1:0:1111|8815b1c9_000047675637:0|0:0:0:1:1")+"&amp;u="+urlencode(this.href))' target="_blank">네이버TV</a>
# <span class="desc">11분 전</span></div></div></div></div><div class="video_scene_bx"><div class="video_scene_wrap type_thumbnail"><div class="video_scene"><a class="title_link _expand" href="#" role="button"><div class="title_thumb"><div class="thumb_box"><img class="thumb" height="23" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMTQ5%2FMDAxNzA5MTIzNTU5MDQ4.jcpwUz14mQiGSBV1K_cC6_kaXW8UYXZsviMwnln4Uawg.-xGMsP6vj2AfheBYNMH1l4BHbk6ZJ9OSH-dv-r2PnQ4g.JPEG%2FC5E18FFA43AD84CD5040F5C42D216341A7BB_0.jpg&amp;type=ac176_100" width="40"/></div></div><div class="title_txt">위 동영상의 주요 장면 5개</div><i class="spnew ico_fold">펼치기</i></a><div class="video_link_wrap"><div class="video_common_player_wrap _svp_target"></div></div><div class="stamp_list_wrap"><div class="api_pcpg_wrap"><div class="api_flicking_wrap _scene_conveyer_root" data-fit-type="exact"><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8815b1c9_000047675637:0" data-cr-area="chapter" data-cr-gparam="1:1:0:1111|8815b1c9_000047675637:0:2|0:0:0:1:1" data-is-visible-close-btn="false" data-seek-time="2" href="https://tv.naver.com/v/47675637?t=2"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMTQ5%2FMDAxNzA5MTIzNTU5MDQ4.jcpwUz14mQiGSBV1K_cC6_kaXW8UYXZsviMwnln4Uawg.-xGMsP6vj2AfheBYNMH1l4BHbk6ZJ9OSH-dv-r2PnQ4g.JPEG%2FC5E18FFA43AD84CD5040F5C42D216341A7BB_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:02</div><div class="dsc">레이더</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8815b1c9_000047675637:0" data-cr-area="chapter" data-cr-gparam="1:1:0:1111|8815b1c9_000047675637:0:15|0:0:0:1:1" data-is-visible-close-btn="false" data-seek-time="15" href="https://tv.naver.com/v/47675637?t=15"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMzEg%2FMDAxNzA5MTIzNTU5MTQz.w0qzQQIP6AdTdIvwRNQH2gF57sw63ui9C9SMpKrSLfAg.9FwIUPBYcP8A64gPaxmE-anP5iNut-imdcSUKjooTBog.JPEG%2FC5E18FFA43AD84CD5040F5C42D216341A7BB_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:15</div><div class="dsc">눈</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8815b1c9_000047675637:0" data-cr-area="chapter" data-cr-gparam="1:1:0:1111|8815b1c9_000047675637:0:25|0:0:0:1:1" data-is-visible-close-btn="false" data-seek-time="25" href="https://tv.naver.com/v/47675637?t=25"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMTUy%2FMDAxNzA5MTIzNTU5Mjcy.Nu1nhVmjSOh4qzOo4DTUxMV2-coJu6wClgqvjkqPCosg.HXvUmcEufykklFQ9pDJ6jeuE5HyW5lP6bznl-IHGZeYg.JPEG%2FC5E18FFA43AD84CD5040F5C42D216341A7BB_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:25</div><div class="dsc">예상 강수량</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8815b1c9_000047675637:0" data-cr-area="chapter" data-cr-gparam="1:1:0:1111|8815b1c9_000047675637:0:31|0:0:0:1:1" data-is-visible-close-btn="false" data-seek-time="31" href="https://tv.naver.com/v/47675637?t=31"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="na ...
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_02_28_1292/4db31efe-d631-11ee-b5f5-a0369ffb3a60.mp4?__gda__=1709154212_985fa3e35e0c53a851d02915272a9ef1" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span aria-label="재생시간 00:54" class="time">00:54</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*G.close&amp;r=2&amp;i=2550431020_88172b92_000047674627&amp;g="+urlencode("2:1:0:1111|88172b92_000047674627:0|0:0:0:1:2")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*G.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*G.kep&amp;r=&amp;i=" data-url="https://tv.naver.com/v/47674627" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*G.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*G.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*G.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="https://tv.naver.com/v/47674627" onclick='return goOtherCR(this,"a=vdo_lst*G.tit&amp;r=2&amp;i=2550431020_88172b92_000047674627&amp;g="+urlencode("2:1:0:1111|88172b92_000047674627:0|0:0:0:1:2")+"&amp;u="+urlencode(this.href))' target="_blank">[월드24 <mark>날씨</mark>] 호주, 산불에 3만 명 대피령</a><div class="info_sub"><div class="desc_group"><a class="channel" href="https://tv.naver.com/kbsnews" onclick='return goOtherCR(this,"a=vdo_lst*G.cha&amp;r=2&amp;i=2550431020_88172b92_000047674627&amp;g="+urlencode("2:1:0:1111|88172b92_000047674627:0|0:0:0:1:2")+"&amp;u="+urlencode(this.href))' target="_blank">KBS뉴스</a><a class="ico_official_area" href="#"><i class="spnew api_ico_official2">공식</i> <span class="tooltip">공식</span></a></div><div class="desc_group"><a class="origin" href="https://tv.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*G.sou&amp;r=2&amp;i=2550431020_88172b92_000047674627&amp;g="+urlencode("2:1:0:1111|88172b92_000047674627:0|0:0:0:1:2")+"&amp;u="+urlencode(this.href))' target="_blank">네이버TV</a>
# <span class="desc">35분 전</span></div></div></div></div><div class="video_common_player_wrap _svp_target"></div></li><li class="video_item _svp_item _ani_type" data-cr-exposure="vdo_lst*K" data-cr-gdid="2550431020_8814ab3d_000047668597" data-cr-gparam="3:1:0:1111|8814ab3d_000047668597:0|0:0:0:1:3" data-cr-rank="3" data-cr-url="https://tv.naver.com/v/47668597"><div class="video_bx _aniitem _video_preview" data-video-selector=".api_mov"><div class="thumb_area"><a class="link _svp_trigger" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8814ab3d_000047668597:0" data-cr-area="thu" data-is-visible-close-btn="false" href="https://tv.naver.com/v/47668597"><img class="thumb api_get api_img" height="104" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fphinf.pstatic.net%2Ftvcast%2F20240228_233%2FUroVX_1709113890305Lewds_JPEG%2Fcover_cover_202402281847492894_t_20240228185101862.jpg&amp;type=ac368_208" width="184"/>
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_02_28_1849/f024ca93-d61e-11ee-8e9d-e4434b2a1c78.mp4?__gda__=1709152370_d519339f931cdabe7e3f67e793f92759" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span class="api_badge_video"><i class="spnew ico_thumbnail"></i>주요장면 3개</span>
# <span aria-label="재생시간 01:10" class="time">01:10</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*K.close&amp;r=3&amp;i=2550431020_8814ab3d_000047668597&amp;g="+urlencode("3:1:0:1111|8814ab3d_000047668597:0|0:0:0:1:3")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*K.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kep&amp;r=&amp;i=" data-url="https://tv.naver.com/v/47668597" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*K.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*K.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="https://tv.naver.com/v/47668597" onclick='return goOtherCR(this,"a=vdo_lst*K.tit&amp;r=3&amp;i=2550431020_8814ab3d_000047668597&amp;g="+urlencode("3:1:0:1111|8814ab3d_000047668597:0|0:0:0:1:3")+"&amp;u="+urlencode(this.href))' target="_blank">[<mark>날씨</mark>] 내일 충청 이남 비...제주·남부 산간 눈</a><div class="info_sub"><div class="desc_group"><a class="channel" href="https://tv.naver.com/ytnnews24" onclick='return goOtherCR(this,"a=vdo_lst*K.cha&amp;r=3&amp;i=2550431020_8814ab3d_000047668597&amp;g="+urlencode("3:1:0:1111|8814ab3d_000047668597:0|0:0:0:1:3")+"&amp;u="+urlencode(this.href))' target="_blank">뉴스는 YTN</a><a class="ico_official_area" href="#"><i class="spnew api_ico_official2">공식</i> <span class="tooltip">공식</span></a></div><div class="desc_group"><a class="origin" href="https://tv.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*K.sou&amp;r=3&amp;i=2550431020_8814ab3d_000047668597&amp;g="+urlencode("3:1:0:1111|8814ab3d_000047668597:0|0:0:0:1:3")+"&amp;u="+urlencode(this.href))' target="_blank">네이버TV</a>
# <span class="desc">2시간 전</span>
# <span class="desc">조회수 1,212</span></div></div></div></div><div class="video_scene_bx"><div class="video_scene_wrap type_thumbnail"><div class="video_scene"><a class="title_link _expand" href="#" role="button"><div class="title_thumb"><div class="thumb_box"><img class="thumb" height="23" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMTY1%2FMDAxNzA5MTE0MjQxMTAy.IjVHD6q8NPQhzNU9NFUaWeH_KiLbl8fYNj0nPS6vmWYg.e9uXoWOmdIhcrpRMzNIUYNEXrKs9pyL_NBkzsq0puGEg.JPEG%2F3E3D02D12A709C140341BB16F34AC9175D92_0.jpg&amp;type=ac176_100" width="40"/></div></div><div class="title_txt">위 동영상의 주요 장면 3개</div><i class="spnew ico_fold">펼치기</i></a><div class="video_link_wrap"><div class="video_common_player_wrap _svp_target"></div></div><div class="stamp_list_wrap"><div class="api_pcpg_wrap"><div class="api_flicking_wrap _scene_conveyer_root" data-fit-type="exact"><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8814ab3d_000047668597:0" data-cr-area="chapter" data-cr-gparam="3:1:0:1111|8814ab3d_000047668597:0:20|0:0:0:1:3" data-is-visible-close-btn="false" data-seek-time="20" href="https://tv.naver.com/v/47668597?t=20"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMTY1%2FMDAxNzA5MTE0MjQxMTAy.IjVHD6q8NPQhzNU9NFUaWeH_KiLbl8fYNj0nPS6vmWYg.e9uXoWOmdIhcrpRMzNIUYNEXrKs9pyL_NBkzsq0puGEg.JPEG%2F3E3D02D12A709C140341BB16F34AC9175D92_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:20</div><div class="dsc">예상 강수량</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8814ab3d_000047668597:0" data-cr-area="chapter" data-cr-gparam="3:1:0:1111|8814ab3d_000047668597:0:33|0:0:0:1:3" data-is-visible-close-btn="false" data-seek-time="33" href="https://tv.naver.com/v/47668597?t=33"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMzMg%2FMDAxNzA5MTE0MjQxMTk3.GAASsoTj_nQr_KQUBSeuPeYR82JMpOv6yohEMGNjxpQg.xeVLLy_TU2oZ7aVgBEM6vYf8HVu0bRZWD0-Lg92tHNMg.JPEG%2F3E3D02D12A709C140341BB16F34AC9175D92_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:33</div><div class="dsc">초미세먼지</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8814ab3d_000047668597:0" data-cr-area="chapter" data-cr-gparam="3:1:0:1111|8814ab3d_000047668597:0:38|0:0:0:1:3" data-is-visible-close-btn="false" data-seek-time="38" href="https://tv.naver.com/v/47668597?t=38"><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMjgw%2FMDAxNzA5MTE0MjQxMjc5.gx-VgcuTRCv0rvITBmMmF8xpWsUK3NGqrzyNw1UGNskg._sPagDHTIZi59jIl-xiIPBsObwH1ccVyCGtPyw3WYdgg.JPEG%2F3E3D02D12A709C140341BB16F34AC9175D92_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:38</div><div class="dsc">수,목,금,토,일</div></div></a></div></div><div class="api_btn_page"><div class="btn_prev _prev" style="display: none;"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.leftbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _next"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.rightbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">다음</i></a></div></div></div></d ...
# <video class="api_mov" height="104" loop="true" muted="" playsinline="" preload="none" webkit-playsinline="" width="184">
# <source src="https://a01-g-naver-vod.akamaized.net/navertv/c/read/v2/VOD_ALPHA/navertv_2024_02_28_681/5e734fc1-d635-11ee-8126-a0369ffdc270.mp4?__gda__=1709156047_d94b97c599949e52e7f14a805e79e23b" type="video/mp4"/></video>
# <span class="mod_thumb_mask"><i class="spnew api_ico_play3">동영상</i></span>
# <span class="api_badge_video"><i class="spnew ico_thumbnail"></i>주요장면 2개</span>
# <span aria-label="재생시간 01:09" class="time">01:09</span>
# </a><a class="close_mask _svp_close" href="#" onclick='return tCR("a=vdo_lst*K.close&amp;r=4&amp;i=1016616097_8800011C_000000000000000001134795&amp;g="+urlencode("4:1:0:1111|8800011C_000000000000000001134795:0550001134795|0:0:0:1:4")+"")' role="button"><span class="close_txt">닫기<i class="spnew ico_close_s"></i></span></a></div><div class="info_area"><div class="api_save_group _keep_wrap"><a aria-pressed="false" class="btn_save _keep_trigger" data-cr-off="a=vdo_lst*K.kep&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kep&amp;r=&amp;i=" data-url="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=055&amp;aid=0001134795" href="#" role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=vdo_lst*K.kepoff&amp;r=&amp;i=" data-cr-on="a=vdo_lst*K.kepon&amp;r=&amp;i=" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='return goOtherCR(this,"a=vdo_lst*K.kephome&amp;r=&amp;i=&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><a class="info_title" href="http://news.naver.com/main/read.naver?mode=LPOD&amp;mid=tvh&amp;oid=055&amp;aid=0001134795" onclick='return goOtherCR(this,"a=vdo_lst*K.tit&amp;r=4&amp;i=1016616097_8800011C_000000000000000001134795&amp;g="+urlencode("4:1:0:1111|8800011C_000000000000000001134795:0550001134795|0:0:0:1:4")+"&amp;u="+urlencode(this.href))' target="_blank">[<mark>날씨</mark>] 제주 최고 40mm 비…내일 남부지방 종일 '쌀쌀'</a><div class="info_sub"><div class="desc_group"><a class="channel" href="http://news.sbs.co.kr/" onclick='return goOtherCR(this,"a=vdo_lst*K.cha&amp;r=4&amp;i=1016616097_8800011C_000000000000000001134795&amp;g="+urlencode("4:1:0:1111|8800011C_000000000000000001134795:0550001134795|0:0:0:1:4")+"&amp;u="+urlencode(this.href))' target="_blank">SBS</a></div><div class="desc_group"><a class="origin" href="http://news.naver.com" onclick='return goOtherCR(this,"a=vdo_lst*K.sou&amp;r=4&amp;i=1016616097_8800011C_000000000000000001134795&amp;g="+urlencode("4:1:0:1111|8800011C_000000000000000001134795:0550001134795|0:0:0:1:4")+"&amp;u="+urlencode(this.href))' target="_blank">네이버 뉴스</a>
# <span class="desc">13분 전</span></div></div></div></div><div class="video_scene_bx"><div class="video_scene_wrap type_thumbnail"><div class="video_scene"><a class="title_link _expand" href="#" role="button"><div class="title_thumb"><div class="thumb_box"><img class="thumb" height="23" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfNDcg%2FMDAxNzA5MTIzMzc2MTM1.LWRLQ4zn4XyPvEW4gn_SJZq1Qda6gwHng53zbN8cbv0g.iuuJsudUd_yF6cChpwBSQdA7uFuRlkbos5AUnJx42Hog.JPEG%2F7DBE6C982A9546E0CAC516BEB8813B3D13E8_0.jpg&amp;type=ac176_100" width="40"/></div></div><div class="title_txt">위 동영상의 주요 장면 2개</div><i class="spnew ico_fold">펼치기</i></a><div class="video_link_wrap"><div class="video_common_player_wrap _svp_target"></div></div><div class="stamp_list_wrap"><div class="api_pcpg_wrap"><div class="api_flicking_wrap _scene_conveyer_root" data-fit-type="exact"><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8800011C_000000000000000001134795:0550001134795" data-cr-area="chapter" data-cr-gparam="4:1:0:1111|8800011C_000000000000000001134795:0550001134795:4|0:0:0:1:4" data-is-visible-close-btn="false" data-seek-time="4" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfNDcg%2FMDAxNzA5MTIzMzc2MTM1.LWRLQ4zn4XyPvEW4gn_SJZq1Qda6gwHng53zbN8cbv0g.iuuJsudUd_yF6cChpwBSQdA7uFuRlkbos5AUnJx42Hog.JPEG%2F7DBE6C982A9546E0CAC516BEB8813B3D13E8_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:04</div><div class="dsc">눈</div></div></a></div><div class="flick_bx"><a class="stamp_item _svp_trigger _scene" data-api="https://s.search.naver.com/p/video/47/search.naver?where=inkey&amp;vid=8800011C_000000000000000001134795:0550001134795" data-cr-area="chapter" data-cr-gparam="4:1:0:1111|8800011C_000000000000000001134795:0550001134795:47|0:0:0:1:4" data-is-visible-close-btn="false" data-seek-time="47" href=""><div class="stamp_thumb_area"><img class="thumb" height="52" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fvideo-search-phinf.pstatic.net%2FMjAyNDAyMjhfMTU5%2FMDAxNzA5MTIzMzc2MjQ4.7jmRUll9nBY-i-1blNV9OWO-X33vw9e9d4MQXdCBjQog.X_ZKlC5h6v-pEyd7bOKON2s9NF6wXtRRhJid4fnKhdMg.JPEG%2F7DBE6C982A9546E0CAC516BEB8813B3D13E8_0.jpg&amp;type=ac176_100" width="91"/></div><div class="stamp_info_area"><div class="stamp_time">00:47</div><div class="dsc">내일</div></div></a></div></div><div class="api_btn_page"><div class="btn_prev _prev" style="display: none;"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.leftbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _next"><a class="btn" href="#" onclick='return tCR("a=vdo_lst.rightbt&amp;r=0&amp;i=&amp;g=")' role="button"><i class="spnew ico_arr">다음</i></a></div></div></div></div></div></div><div class="mod_ly_notice">영상 내 주요 장면을 탐색할 수 있어요.</div></div></li></ul><div class="mod_more_wrap"><a class="group_more" href="?query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_nmr&amp;where=video" onclick='return goOtherCR(this,"a=vdo_lst.more&amp;r=0&amp;i=&amp;g=&amp;u="+urlencode(this.href))'><span class="kwd">동영상</span>
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/video/app-1.9.0.js",t=function(){var e=window.require.config({context:"search_common_modules"});e(["VideoPlayer2"],n)},n=function(){var t=window.require.config({context:"video",paths:{"@sfe/togglor":"https://ssl.pstatic.net/sstatic/au/module/togglor/togglor-1.3.1.min","@sfe/video-preview":"https://ssl.pstatic.net/sstatic/fe/sfe/video-preview/Controller_231123_a",app:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),define("@sfe/search-video-player2",[],function(){return naver.common.VideoPlayer2}),t(["jquery","app"],function(e,t){t({$root:e("._fe_video"),type:"pc",isTab:!1,report:{api:"https://s.search.naver.com/n/srm/report"}})})};naver.common.load_js(null,t,!0,60)})()</script><section class="sc_new sp_ntotal _sp_ntotal _prs_web_gen _fe_root_web_gen"><div class="api_subject_bx"><ul class="lst_total"><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://weawow.com/ko/c9488823/tomorrow" href="#" onclick='tCR("a=web_gen*w.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen*w.keepoff" data-cr-on="a=web_gen*w.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=0&amp;i=a00000fa_8c1ad6acd2629f9f6d99cebc&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://weawow.com/ko/c9488823/tomorrow" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=a00000fa_8c1ad6acd2629f9f6d99cebc&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fdesign.weawow.com%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://weawow.com/ko/c9488823/tomorrow" target="_blank">
# weawow.com<i class="divide">›</i>ko</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://weawow.com/ko/c9488823/tomorrow" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=a00000fa_8c1ad6acd2629f9f6d99cebc&amp;u="+urlencode(this.href))' target="_blank"><mark>여의도</mark> 대한민국 내일 <mark>날씨</mark>, 14일 일기 예보, 레이더 &amp; 사진들 - Weawow</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://weawow.com/ko/c9488823/tomorrow" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=0&amp;i=a00000fa_8c1ad6acd2629f9f6d99cebc&amp;u="+urlencode(this.href))' target="_blank"><mark>여의도</mark> 대한민국 내일 <mark>날씨</mark>: 현재, 시간별, 14일 일기 예보, 레이더, 강수, 자외선 지수, 바람 , 사진 작가의 <mark>날씨</mark> 사진.</a></div></div></div><div class="source_cluster_wrap"><div class="source_cluster_list"><div class="source_item"><a class="source_thumb _parent" href="https://weawow.com/ko/c9488823" onclick='goOtherCR(this,"a=web_gen*w.simg&amp;r=1&amp;i=a00000fa_bfe791fcf701fdd8d166bb76%5El&amp;u="+urlencode(this.href))' target="_blank"><img alt="" class="api_get" data-img-alias="hide" data-img-eparam="._parent" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fd2idu5mmj5r5g3.cloudfront.net%2Fphotos_m%2F4SJN36Y0aH86736.jpg&amp;type=fff174_174" height="48" src="..." width="48"/>
# </a><a class="source_title" href="https://weawow.com/ko/c9488823" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_bfe791fcf701fdd8d166bb76%5El&amp;u="+urlencode(this.href))' target="_blank"><mark>여의도</mark> 대한민국, 14일 일기 예보, 레이더 &amp; 사진들 - Weawow</a><div class="source_dsc"><mark>여의도</mark> 대한민국: 현재, 시간별, 14일 일기 예보, 레이더, 강수, 자외선 지수, 바람 , 대기질, 사진 작가의 <mark>날씨</mark> 사진.</div></div></div></div><div class="total_more_wrap"><a class="total_more" href="?query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8+site%3Aweawow.com&amp;where=web" onclick='goOtherCR(this,"a=web_gen*w.sramore&amp;r=&amp;i=&amp;u="+urlencode(this.href))'>관련문서 더보기<i class="spnew api_ico_arr4"></i></a></div></li><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="https://www.accuweather.com/ko/kr/yeoui-dong/225999/hourly-weather-forecast/225999" href="#" onclick='tCR("a=web_gen*w.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen*w.keepoff" data-cr-on="a=web_gen*w.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=2&amp;i=a00000fa_99c8b886fae762f40028f241&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="https://www.accuweather.com/ko/kr/yeoui-dong/225999/hourly-weather-forecast/225999" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=2&amp;i=a00000fa_99c8b886fae762f40028f241&amp;u="+urlencode(this.href))' target="_blank"><img alt="" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.accuweather.com%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="..." width="16"/></a><a class="txt" href="https://www.accuweather.com/ko/kr/yeoui-dong/225999/hourly-weather-forecast/225999" target="_blank">
# www.accuweather.com<i class="divide">›</i>kr<i class="divide">›</i>yeoui-dong<i class="divide">›</i>hourly-weather-forecast</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="https://www.accuweather.com/ko/kr/yeoui-dong/225999/hourly-weather-forecast/225999" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=2&amp;i=a00000fa_99c8b886fae762f40028f241&amp;u="+urlencode(this.href))' target="_blank">여의동, 서울시, 대한민국 시간별 <mark>날씨</mark> | AccuWeather</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="https://www.accuweather.com/ko/kr/yeoui-dong/225999/hourly-weather-forecast/225999" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=2&amp;i=a00000fa_99c8b886fae762f40028f241&amp;u="+urlencode(this.href))' target="_blank">Hourly weather forecast in 여의동, 서울시, 대한민국. Check current conditions in 여의동, 서울시, 대한민국 with radar, hourly, and more.</a></div></div></div></li><li class="bx"><div class="total_wrap"><div class="total_tit_group"><div class="total_source"><div class="api_save_group _keep_wrap"><a class="btn_save _keep_trigger" data-url="http://townforecast.nalsee.com/ThemaForecast/ThemaForecast.aspx?themaCategoryNo=2&amp;categoryType=%EA%B3%B5%EC%9B%90&amp;selectRegionNo=2487" href="#" onclick='tCR("a=web_gen*w.kep&amp;r=&amp;i=&amp;u=javascript")' role="button"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen*w.keepoff" data-cr-on="a=web_gen*w.keepon" href="#" role="button">Keep에 저장</a>
# <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=3&amp;i=a00000fa_f10351606895719b2b0a2b55%5Ex&amp;u="+urlencode(this.href))' target="_blank">Keep 바로가기</a></div></div><div class="source_box"><a class="thumb" href="http://townforecast.nalsee.com/ThemaForecast/ThemaForecast.aspx?themaCategoryNo=2&amp;categoryType=%EA%B3%B5%EC%9B%90&amp;selectRegionNo=2487" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=3&amp;i=a00000fa_f10351606895719b2b0a2b55%5Ex&amp;u="+urlencode(this.href))' target="_blank"><i class="sptotal ico_favicon_default"></i></a><a class="txt" href="http://townforecast.nalsee.com/ThemaForecast/ThemaForecast.aspx?themaCategoryNo=2&amp;categoryType=%EA%B3%B5%EC%9B%90&amp;selectRegionNo=2487" target="_blank">
# townforecast.nalsee.com<i class="divide">›</i>ThemaForecast</a></div></div></div><div class="total_group"><div class="total_tit"><a class="link_tit" href="http://townforecast.nalsee.com/ThemaForecast/ThemaForecast.aspx?themaCategoryNo=2&amp;categoryType=%EA%B3%B5%EC%9B%90&amp;selectRegionNo=2487" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=3&amp;i=a00000fa_f10351606895719b2b0a2b55%5Ex&amp;u="+urlencode(this.href))' target="_blank"><mark>여의도</mark> 한강공원 - 우리 동네예보-<mark>날씨</mark>닷컴</a></div><div class="total_dsc_wrap"><a class="api_txt_lines total_dsc type_3lines" href="http://townforecast.nalsee.com/ThemaForecast/ThemaForecast.aspx?themaCategoryNo=2&amp;categoryType=%EA%B3%B5%EC%9B%90&amp;selectRegionNo=2487" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=3&amp;i=a00000fa_f10351606895719b2b0a2b55%5Ex&amp;u="+urlencode(this.href))' target="_blank"><mark>여의도</mark> 한강공원 | 공원 | 서울특별시 영등포구 여의동 · http://hangang.seoul.go.kr/ <mark>여의도</mark>한강공원은 정치, 금융, 언론의 중심지인 <mark>여의도</mark>에 자리하고 지하철, 버스 등 대중교통으로 접근성이 좋아 직장인과 일반시민들이 즐겨찾는 명소이자 봄꽃축제, 세계불꽃축제, 각종 공연 및 마라톤행사 등 다양한 행사가 이어져 볼거리와 즐길거리가 풍부한 휴식공간입니다. 또한 밤섬, <mark>여의도</mark> 샛강 등이 비교적 자연그대로 보존 ...</a></div></div></div></li></ul><div class="mod_more_wrap"><a class="group_more" href="?nso=&amp;page=2&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=web_gen*w.more2&amp;r=&amp;i=&amp;u="+urlencode(this.href))'><span class="kwd">검색결과</span>
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc_240116.js",t=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var t=jQuery("._fe_root_web_gen"),n=new e(t);n.on({"tab-scroll":function(e){e.isTrusted},"content-scroll":function(e){if(e.isTrusted){var t=e.$wrapper.find("._freescroll_flicking").attr("data-log");t&&tCR(t)}},"click-infolayer-trigger-button":function(e){e.isOn}})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e,n="_sp_ntotal",s="type_margin",t=Array.prototype.slice.call(document.querySelectorAll("section."+n));function o(e,t){return e.matches?e.matches(t):!!e.msMatchesSelector&&e.msMatchesSelector(t)}function i(e){var t=e,s=t.tagName.toLowerCase();do t=t.previousElementSibling,s=t?t.tagName.toLowerCase():"";while(t!==null&&(s==="script"||s==="link"))return t!==null&&s==="section"&&o(t,"."+n)}for(e=0;e<t.length;++e)i(t[e])&&t[e].classList.add(s)})()</script><div class="api_sc_page_wrap"><div class="sc_page"><a aria-disabled="true" class="btn_prev" role="button"><i class="spnew api_ico_pg_arr">이전</i></a><div class="sc_page_inner"><a aria-pressed="true" class="btn" href="?nso=&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;where=nexearch" onclick='goOtherCR(this,"a=pag.pag&amp;r=1&amp;i=&amp;u="+urlencode(this.href))' role="button">1</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=2&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=2&amp;i=&amp;u="+urlencode(this.href))' role="button">2</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=3&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=3&amp;i=&amp;u="+urlencode(this.href))' role="button">3</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=4&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=4&amp;i=&amp;u="+urlencode(this.href))' role="button">4</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=5&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=5&amp;i=&amp;u="+urlencode(this.href))' role="button">5</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=6&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=6&amp;i=&amp;u="+urlencode(this.href))' role="button">6</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=7&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=7&amp;i=&amp;u="+urlencode(this.href))' role="button">7</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=8&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=8&amp;i=&amp;u="+urlencode(this.href))' role="button">8</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=9&amp;query=%EC%97%AC%EC%9D%98%EB%8F%84+%EB%82%A0%EC%94%A8&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=9&amp;i=&amp;u="+urlencode(this.href))' role="button">9</a>
# ...
# <em class="badge"><span class="txt">오늘 인기</span></em></div><div class="info_area"><div class="name">백컨트리320쉘터</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%ba%a0%ed%95%91%ed%99%94%eb%a1%9c%eb%8c%80%ed%85%8c%ec%9d%b4%eb%b8%94" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=2&amp;i=SYS-0000000006503653.98226stj_A4402C0E94018A1F940272E6BC8931E2&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%222%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_2807847%2F28078470522.20220421144832.jpg&amp;type=f174_174" width="84"/>
# <em class="badge"><span class="txt">오늘 인기</span></em></div><div class="info_area"><div class="name">캠핑화로대테이블</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%af%b8%eb%8b%88%ec%ba%a0%ed%95%91%ed%85%8c%ec%9d%b4%eb%b8%94" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=3&amp;i=SYS-0000000006503653.98226stj_A389F6A4AC951B18251E2483A0C4DA3D&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%223%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8556830%2F85568307363.1.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">미니캠핑테이블</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%9d%b4%ea%b7%b8%eb%8b%88%ec%8a%a4L%ec%89%98%ed%84%b0" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=4&amp;i=SYS-0000000006503653.98226stj_44D4C3728323329FB11EA99B6BB4A357&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%224%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8457470%2F84574700694.jpg&amp;type=f174_174" width="84"/>
# <em class="badge"><span class="txt">2월 인기</span></em></div><div class="info_area"><div class="name">이그니스L쉘터</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%9e%9c%eb%93%9c%eb%9d%bd%ec%95%84%ec%9d%b4%eb%b3%b4%eb%a6%ac" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=5&amp;i=SYS-0000000006503653.98226stj_39481CC5EDD63A2E7D2B0BCDD56A79AA&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%225%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8344542%2F83445427577.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">랜드락아이보리</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%97%90%ec%bd%94%ed%94%8c%eb%a1%9c%ec%9a%b0%eb%8d%b8%ed%83%801300" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=6&amp;i=SYS-0000000006503653.98226stj_CBDC8AB6964227C6CA0B8A9872C1FECE&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%226%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_2863154%2F28631545130.20220413094834.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">에코플로우델타1300</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%b2%a0%eb%a5%b8%ed%8a%b8%eb%a0%88%ed%82%b9%ed%8c%a8%eb%93%9c" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=7&amp;i=SYS-0000000006503653.98226stj_09E08F4DEDF9928FCC5072DF951723A1&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%227%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_3317738%2F33177387618.20220628170652.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">베른트레킹패드</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%97%90%ec%96%b4%ec%8a%a4%ed%8a%b8%eb%a6%bc" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=8&amp;i=SYS-0000000006503653.98226stj_F3A51DAA573EA8ED5CBC9160291D1E3B&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%228%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8644526%2F86445269053.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">에어스트림</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%bd%94%eb%b2%a0%ec%95%84%ea%b3%a0%ec%8a%a4%ed%8a%b8%ec%89%98%ed%84%b0" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=9&amp;i=SYS-0000000006503653.98226stj_4537D71D96F9CDE373BDB0B826BFA5D3&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%229%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8625928%2F86259283090.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">코베아고스트쉘터</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ed%88%ac%eb%aa%85%ed%85%90%ed%8a%b8" onclick="return goOtherCR(this,'a=shX_ssC*w ...
# <em class="badge"><span class="txt">겨울 인기</span></em></div><div class="info_area"><div class="name">투명텐트</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ed%8c%8c%ec%9d%b4%ec%96%b4%ec%8a%a4%ed%8b%b1" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=11&amp;i=SYS-0000000006503653.98226stj_2C2A5F615881C026C6D908324B2300A9&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%2211%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_4557074%2F45570744194.20240131193128.jpg&amp;type=f174_174" width="84"/>
# <em class="badge"><span class="txt">겨울 인기</span></em></div><div class="info_area"><div class="name">파이어스틱</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%b9%85%ed%86%a0%eb%a6%ac%ec%ba%a0%ed%94%84" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=12&amp;i=SYS-0000000006503653.98226stj_A2095E4E942A0854AC576AF94AA99308&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%2212%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8489378%2F84893783916.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">빅토리캠프</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%9c%a0%ed%8b%b8%eb%a6%ac%ed%8b%b0%eb%82%98%ec%9d%b4%ed%94%84" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=13&amp;i=SYS-0000000006503653.98226stj_E9ED0343BF9C31F5F4A39867D01E8B9A&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%2213%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8518315%2F85183153755.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">유틸리티나이프</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%8a%a4%ed%83%80%eb%b2%85%ec%8a%a4%ec%bf%a8%eb%9f%ac%eb%b0%b1" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=14&amp;i=SYS-0000000006503653.98226stj_E6DBC57C3A45FE662B63BB40C9134CB6&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%2214%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_4157673%2F41576736553.20230802175703.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">스타벅스쿨러백</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%eb%a1%9c%ec%bc%93%ec%8a%a4%ed%86%a0%eb%b8%8c" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=15&amp;i=SYS-0000000006503653.98226stj_30D6A073862D01FF7B9223444639BD7A&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%2215%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_3022519%2F30225198026.20220325130316.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">로켓스토브</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ed%94%84%eb%a6%ac%eb%aa%a8%eb%a6%ac%ec%95%84%eb%a6%ac%ec%9b%80" onclick="return goOtherCR(this,'a=shX_ssC*w.kyw&amp;r=16&amp;i=SYS-0000000006503653.98226stj_5F8B90AC6307B58328B02F4BCD36EBF9&amp;g=%7B%22bid%22%3A%22SYS-0000000006503653%22%2C%22docRank%22%3A%2216%22%7D&amp;u='+urlencode(this.href))"><div class="thumb_area"><img class="api_get" height="84" onerror="naver.common.handleImgError(this)" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_8447453%2F84474534957.jpg&amp;type=f174_174" width="84"/></div><div class="info_area"><div class="name">프리모리아리움</div></div></a></div><div class="flick_bx"><a class="item_card" href="?where=nexearch&amp;mra=U1BI&amp;sm=tab_clk.shp&amp;query=%ec%9e%90%ea%b0%80%eb%b0%9c%ec%a0%84%ec%86%90%ec%a0%84%eb%93%b1" onclick="return goOtherCR(this,'a=shX_ssC*w.ky ...
# <strong class="tit_message">죄송합니다. 일시적인 오류입니다.</strong><p class="dsc_message">잠시 후 다시 시도해주십시오.</p><a class="btn_retry _retry" href="javascript:;"><i class="spnew api_ico_retry"></i>재시도</a></div></div></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/smartblock/pc/Controller.min_230920.js",t=function(){var t=window.require.config({paths:{Controller:e.replace(/\.js$/,"")}}),n=jQuery("._fe_smartblock_shop_weather_2th");t(["Controller"],function(e){var t=new e({$base:n,response:"block.html"});t.on({})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2402-travel-002&amp;target=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fmra%3DUlJUX1RJTQ%3D%3D%26where%3Dnexearch%26sm%3Dtop_hty%26fbm%3D0%26ie%3Dutf8%26query%3D%25EB%25B4%2584%25EC%2597%25AC%25ED%2596%2589%25EC%25A7%2580%25EC%25B6%2594%25EC%25B2%259C%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2402-travel-002" nocr="" onclick="return goOtherCR(this, 'a=bnr.link1&amp;r=1&amp;i=&amp;u=' + urlencode(this.href));"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240228_31/1709100588557RRkaN_PNG/760_31963112_marketing_banner_pc_icon_0_1709100588542.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">봄바람 살랑이면 생각나는 곳</strong> <p class="elss dsc">국내 봄 여행지 모아보기</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2309-cue-001&amp;material=&amp;target=https%3A%2F%2Fcue.search.naver.com%2F%3Ffrom%3Dsearch_pc2nd" nocr="" onclick="return goOtherCR(this, 'a=bnr.link2&amp;r=2&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20231117_138/1700187409948YGazA_PNG/760_31963112_marketing_banner_pc_icon_1_1700187409320.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">AI 검색, 아직 안 써봤다면?</strong> <p class="elss dsc">네이버 Cue: 사전 신청하기</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2311-clovax-001&amp;material=&amp;target=https%3A%2F%2Fclova-x.naver.com%2F" nocr="" onclick="return goOtherCR(this, 'a=bnr.link3&amp;r=3&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20231117_63/1700187410127JIVFp_PNG/760_31963112_marketing_banner_pc_icon_2_1700187409322.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">CLOVA X와 함께 대화해 보세요</strong> <p class="elss dsc">대화형 AI 서비스 시작하기 </p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2401-mem-001&amp;target=https%3A%2F%2Fnid.naver.com%2Fmembership%2Fjoin%3Fdtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2401-mem-001" nocr="" onclick="return goOtherCR(this, 'a=bnr.link4&amp;r=4&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240227_64/1709023555357lvTGc_PNG/760_31963112_marketing_banner_pc_icon_3_1709023555347.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">이번 달은 꼭 적립 받고 사세요!</strong> <p class="elss dsc">최대 5% 적립 네이버플러스 멤버십</p> </div> </a> </div> </div> </section> <script> var nx_cr_right_area_info = [{"n": "rsk_top", "r": 1},{"n": "shX_ssC", "r": 2},{"n": "bnr", "r": 3}]; </script></div><div class="ly_dimmed"></div> </div> </div><div id="footer"> <div class="sub_pack_btm"> <a class="top" href="#" onclick="window.scrollTo(0,0); document.querySelect ...

# %% [markdown]
# Copy selector 를 이용하여 가져오기

# %%
# 4. 기온 요소 추출
result_list = [] # 결과물을 저장할 리스트 생성
copy_selector = "#main_pack > section.sc_new.cs_weather_new._cs_weather > div > div:nth-child(1) > div.content_wrap > div.open > div:nth-child(1) > div > div.weather_info > div > div._today > div.weather_graphic > div.temperature_text > strong"
copy_data = bs_result.select_one(copy_selector)
copy_text = copy_data.get_text(separator=",")
result_list.append(copy_text)
result_list
# Out:
# ['현재 온도,7.4,°']

# %% [markdown]
# 두 번에 걸쳐서 가져오기 - 번외

# %%
today_temperature = bs_result.find("div", class_="_today")
data = today_temperature.find("div", class_="temperature_text")
data
# Out:
# <div class="temperature_text"> <strong><span class="blind">현재 온도</span>7.7<span class="celsius">°</span></strong> </div>

# %%
now_temperature = data.get_text(separator=",")
now_temperature
# Out:
# ' ,현재 온도,7.7,°, '

# %% [markdown]
# 한 번에 가져와서 찾아보기 - 번외

# %%
temperature = bs_result.find_all("div", class_="temperature_text")
temperature
# Out:
# [<div class="temperature_text"> <strong><span class="blind">현재 온도</span>7.7<span class="celsius">°</span></strong> </div>,
#  <div class="temperature_text"> <strong><span class="blind">예측 온도</span>2<span class="celsius">°</span></strong> </div>,
#  <div class="temperature_text"> <strong><span class="blind">예측 온도</span>9<span class="celsius">°</span></strong> </div>,
#  <div class="temperature_text"> <strong><span class="blind">예측 온도</span>4<span class="celsius">°</span></strong> </div>,
#  <div class="temperature_text"> <strong><span class="blind">예측 온도</span>8<span class="celsius">°</span></strong> </div>]

# %%
now_temperature = temperature[0].get_text(separator=",")
now_temperature
# Out:
# ' ,현재 온도,7.7,°, '

# %% [markdown]
# 날씨확인

# %%
# 5. 날씨 요소 추출
weather = bs_result.find("span", class_="weather")
weather_result = weather.text
result_list.append(weather_result)
result_list
# Out:
# ['현재 온도,7.4,°', '흐림']

# %%
result_list
# Out:
# ['현재 온도,7.7,°', '흐림']
