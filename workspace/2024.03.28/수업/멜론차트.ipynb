# %%
# 1. 모듈 임포트
import requests
from bs4 import BeautifulSoup

# %%
# 봇 차단 방지 헤더 추가 (https://www.whatismybrowser.com/detect/what-is-my-user-agent/)
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36"}
url = "https://www.melon.com/chart/index.htm" # 멜론 top100주소
page = requests.get(url, headers=header)

# %%
# 3. BeatifulSoup 으로 파싱
bs_result = BeautifulSoup(page.text, "html.parser")
bs_result

# %%
result_list = [] # 결과물 저장 리스트 생성

# %%
# 
copy_selector = "#frm > div > table > tbody" 
# #lst50 > td:nth-child(6)

selector = "#1st50 > td:nth-child(6)"
data = bs_result.select(copy_selector+ "> tr") # select : find_all 과 비슷함
len(data)
# Out:
# 100

# %%
for item in data:
    print(item.text)
    # print(len(item.text))
# Out:
# 1위
#
#
#
# 순위 동일
# 0
#
#
#
#
#
#
#
#
#
# 곡정보
#
#
#
#
# 나는 아픈 건 딱 질색이니까
#
#
# (여자)아이들(여자)아이들
#
#
#
#
#
#
# 2
#
#
#
#
#
# 좋아요
#
# 총건수
# 												0
#
#
#
#
# 듣기
#
#
# 담기
#
#
# 다운로드
#
#
# 뮤직비디오
#
#
#
#
# 2위
#
#
#
# 순위 동일
# 0
#
#
#
#
#
#
#
#
#
# 곡정보
#
#
#
#
# 첫 만남은 계획대로 되지 않아
#
#
# TWS (투어스)TWS (투어스)
#
#
#
#
#
#
# TWS 1st Mini Album ‘Sparkling Blue’
#
#
#
#
#
# 좋아요
#
# 총건수
# 												0
#
#
#
#
# 듣기
#
#
# 담기
#
#
# 다운로드
#
#
# 뮤직비디오
#
#
#
#
# 3위
#
#
#
# 순위 동일
# 0
#
#
#
#
#
#
#
#
#
# 곡정보
#
#
#
#
# 밤양갱
#
#
# 비비 (BIBI)비비 (BIBI)
#
#
#
#
#
#
# 밤양갱
#
#
#
#
#
# 좋아요
#
# 총건수
# 												0
#
#
#
#
# 듣기
#
#
# 담기
#
#
# 다운로드
#
#
# 뮤직비디오
#
#
#
#
# 4위
#
#
#
# 순위 동일
# 0
#
#
#
#
#
#
#
#
#
# 곡정보
#
#
#
#
# EASY
#
#
# LE SSERAFIM (르세라핌)LE SSERAFIM (르세라핌)
#
#
#
#
#
#
# EASY
#
#
#
#
#
# 좋아요
#
# 총건수
# 												0
#
#
#
#
# 듣기
#
#
# 담기
#
#
# 다운로드
#
#
# 뮤직비디오
#
#
#
#
# 5위
#
#
#
# 순위 동일
# 0
#
#
#
#
#
#
#
#
#
# 곡정보
#
#
#
#
# Love wins all
#
#
# 아이유아이유
#
#
#
#
#
#
# The Winning
#
#
#
#
#
# 좋아요
#
# 총건수
# ...
