# %%
import os
import sys
import urllib.request
client_id = "vw6bVqqh3uzvU7XTQ228"
client_secret = "lClfV7orOX"
encText = urllib.parse.quote("버츄얼휴먼 성공")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 28 Mar 2024 16:04:07 +0900",
# 	"total":364,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[News Clipping] amPRist's Pick : <b>버츄얼 휴먼<\/b>",
# 			"link":"https:\/\/blog.naver.com\/amprists\/222950887829",
# 			"description":"국내에서 얻은 유명세를 바탕으로, 온마인드의 <b>버츄얼 휴먼<\/b> 나수아는 태국 시장 진출에 <b>성공<\/b>해 태국 DDD(Dynamic Digital Display)와 3년간 전속 계약을 체결해 방콕 랜드마크 곳곳에 등장하게 되었다고 합니다.... ",
# 			"bloggername":"Marketing PR Review : 에이엠피알(amPR) 기업블로그",
# 			"bloggerlink":"blog.naver.com\/amprists",
# 			"postdate":"20221209"
# 		},
# 		{
# 			"title":"[강콘PD] <b>버츄얼 휴먼<\/b>",
# 			"link":"https:\/\/blog.naver.com\/moebius2022\/222855446970",
# 			"description":"로지는 MZ세대가 좋으하는 외모를 지니고 있기에 친한친구처럼 진입 장벽이 낮은데요~ 로지는 연간 수입 10억원을 벌어드릴 정도로 큰 <b>성공<\/b>을 이룬 버.츄.얼.휴.먼 (*인스스:인스타스타) 또 다른 <b>버츄얼 휴먼<\/b>으로... ",
# 			"bloggername":"뫼비우스",
# 			"bloggerlink":"blog.naver.com\/moebius2022",
# 			"postdate":"20220822"
# 		},
# 		{
# 			"title":"벨리곰과 롯데에 밀린 신세계, <b>버츄얼 휴먼<\/b>·편의점·호텔... ",
# 			"link":"https:\/\/blog.naver.com\/dream_127\/222915899282",
# 			"description":"<b>버츄얼 휴먼<\/b>이 아직 마케팅에 있어 별 효과를 보는 것 같지는 않지만, 롯데는 <b>성공<\/b>적인 캐릭터 '벨리곰'을 통해 자연스러운 홍보에 <b>성공<\/b>했다. 벨리곰의 경우 해외 진출은 물론 미국 테마파크에까지 진출할... ",
# 			"bloggername":"ＦＲＥＥＺＥ",
# 			"bloggerlink":"blog.naver.com\/dream_127",
# 			"postdate":"20221031"
# 		},
# 		{
# 			"title":"메타버스와 <b>버츄얼휴먼<\/b>(1)_what is the next step of... ",
# 			"link":"https:\/\/blog.naver.com\/wave_n_particle\/223081378061",
# 			"description":"추가로, 상업적으로 <b>성공<\/b>한 콘텐츠의 공통점으로는 ‘서사성'에 있다고 보인다. <b>버츄얼 휴먼<\/b>을 예시로 생각해보자. 릴 미켈라와 로지는 현실을 바탕으로 설정되며, 다른 실존 인플루언서들과의 일시적인... ",
# 			"bloggername":"wavicle",
# 			"bloggerlink":"blog.naver.com\/wave_n_particle",
# 			"postdate":"20230421"
# 		},
# 		{
# 			"title":"<b>버츄얼 휴먼<\/b> 마케팅이 인기를 끄는 이유는?",
# 			"link":"https:\/\/blog.naver.com\/iadone100\/222969389070",
# 			"description":"오늘은 아이애드원과 함께 버추얼 <b>휴먼<\/b>이 인기있는 이유와 화제가 된 <b>성공<\/b>마케팅 사례들에 대해 알아보도록 하겠습니다. 버추얼 <b>휴먼<\/b> 마케팅이 인기 있는 이유는? 기업은 브랜드가 추구하고자 하는 방향에... ",
# 			"bloggername":"온라인광고대행사 아이애드원",
# 			"bloggerlink":"blog.naver.com\/iadone100",
# 			"postdate":"20221230"
# 		},
# 		{
# 			"title":"[스토리] 삼성 LG AI <b>버츄얼 휴먼<\/b> 미래 먹거리 선점 가상인간... ",
# 			"link":"https:\/\/blog.naver.com\/storytrading\/222737438750",
# 			"description":"가능한 '<b>버츄얼 휴먼<\/b>' 개발 중 3. 관련주 매매 전략 &amp; 향후 전망 로지', '이세계 아이돌' 등 가상... 공부하시고 <b>성공<\/b>투자 시작하세요 텔레그램 무료 구독: https:\/\/t.me\/storytrading1 오픈 카카오 무료 입장: https... ",
# 			"bloggername":"스토리트레이딩",
# 			"bloggerlink":"blog.naver.com\/storytrading",
# 			"postdate":"20220518"
# 		},
# 		{
# 			"title":"<b>버츄얼 휴먼<\/b>으로 만나는 공존의 시대 - 디오비스튜디오",
# 			"link":"https:\/\/blog.naver.com\/sdibattery\/222869218465",
# 			"description":"버추얼 <b>휴먼<\/b>의 <b>성공<\/b> 사례로 꼽힌다. 영원히 늙지 않으면서 시간과 체력 문제는 물론, 구설수에 오를 일이 없어 사생활 논란에서도 자유로운 점 등이 요즘 버추얼 <b>휴먼<\/b>이 각광받는 이유이다. 외면하기엔 이미 그... ",
# 			"bloggername":"삼성SDI 공식 블로그",
# 			"bloggerlink":"blog.naver.com\/sdibattery",
# 			"postdate":"20220908"
# 		},
# 		{
# 			"title":"[ICT활용 세미나] 카이스트 김숙경 교수, <b>버츄얼 휴먼<\/b> 이상민... ",
# 			"link":"https:\/\/olivia-blackcherry.tistory.com\/601",
# 			"description":"하지만 기술을 알고 문제를 해결했다면 그것은 <b>성공<\/b>으로 가는 지름길이 된다. 최고의 기술이 아니라... 사용기술: 딥러닝(딥페이크) &gt; VFX기술 &gt; 3D모델링 모션캡쳐 오브카 OVHCA 세계관을 넣어 <b>버츄얼휴먼<\/b>을... ",
# 			"bloggername":"올리비아 코딩스쿨",
# 			"bloggerlink":"https:\/\/olivia-blackcherry.tistory.com\/",
# 			"postdate":"20230726"
# 		},
# 		{
# 			"title":"[경영] 버추얼 <b>휴먼<\/b> _ 셀링 <b>성공<\/b> 포인트, 비지니스 활용도 이해... ",
# 			"link":"https:\/\/blog.naver.com\/tangamja76\/222664957455",
# 			"description":"이러한 흐름으로 본다면, <b>버츄얼 휴먼<\/b>은 이미 우리의 욕구를 반영한 현상일지도 모른다. 인공지능, 가상현실, 메타버스, 증강현실 등 디지털 세상에서 버추얼 <b>휴먼<\/b>의 영역이 앞으로도 얼마나 더 다양해 질까. 이... ",
# 			"bloggername":"소소한 행복을 만드는 나의 세상",
# 			"bloggerlink":"blog.naver.com\/tangamja76",
# 			"postdate":"20220306"
# 		},
# 		{
# 			"title":"(이세돌), 제이나 아나운서... 본체는 누구일까? feat. 디지털 <b>휴먼<\/b>",
# 			"link":"https:\/\/blog.naver.com\/jessymoa\/223381128782",
# 			"description":"<b>버츄얼 휴먼<\/b> 제주도청 AI 버추얼 아나운서 제이나 (J-NA) 이외에도 다양한 버추얼 <b>휴먼<\/b>들이 양산되고... 가수의 <b>성공<\/b>이 가능할 수도 있구나 했었습니다. 이번에 공중파 음악방송에서 쟁쟁한 후보들을 제치고... ",
# 			"bloggername":"몰입하는 순간의 연속",
# 			"bloggerlink":"blog.naver.com\/jessymoa",
# 			"postdate":"20240312"
# 		}
# 	]
# }

# %%
import json
text_data = response_body.decode('utf-8')
json_data = json.loads(text_data)
print(json_data)
# Out:
# {'lastBuildDate': 'Thu, 28 Mar 2024 16:02:15 +0900', 'total': 41301093, 'start': 1, 'display': 10, 'items': [{'title': '핸드드립 맷돌<b>커피</b> 김해 삼계동카페 다반사', 'link': 'https://blog.naver.com/1004ykw/223395659112', 'description': '맷돌<b>커피</b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피</b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도... ', 'bloggername': '너는 모르는 여자이야기', 'bloggerlink': 'blog.naver.com/1004ykw', 'postdate': '20240326'}, {'title': '수영, <b>커피</b>가 맛있는 조용한 카페 오우커 <b>커피</b> 바', 'link': 'https://blog.naver.com/pajamasis09/223397855270', 'description': '앞서 적은 광안리애에서 맛있는 식사 후 컨디션은 여전히 좋지 않았지만 식후 <b>커피</b>는 놓칠 수 없었기에!! 바로 근처 <b>커피</b>가 맛있다는 카페가 있어 큰 고민 없이 향했습니다 동네 특성상 작고 작은 가게들이... ', 'bloggername': 'EVERYDAY HAPPY SMILE ❤️', 'bloggerlink': 'blog.naver.com/pajamasis09', 'postdate': '20240328'}, {'title': '부천 시청역 슈퍼브<b>커피</b>로스터스 <b>커피</b> 맛집', 'link': 'https://blog.naver.com/kiti5447/223397966836', 'description': '부천 <b>커피</b> 맛집 테이크아웃<b>커피</b> 전문점 슈퍼브<b>커피</b>로스터스 안녕하세요. 류짱입니다. 벌써 한 주가 지나고 3월도 마지막 주가 되었는데요. 정말 3월에는 아이가 학교에 입학하고 나서 정신없이 시간이... ', 'bloggername': '류짱의 맛집 여행', 'bloggerlink': 'blog.naver.com/kiti5447', 'postdate': '20240328'}, {'title': '강릉 카페 이진리 / 시그니처 후추<b>커피</b> 대존맛', 'link': 'https://blog.naver.com/hyuni2mail/223397084072', 'description': '중에서 <b>커피</b>가 맛있는 곳, 특히 시그니처인 후추<b>커피</b>가 맛있는 카페인 강릉 이진리 카페를 찾아갔어요 :) 요즘 떠오르는 강릉 맛집이라는 감자유원지 후기가 궁금하시다면 위 링크 클릭해서 같이 보셔도... ', 'bloggername': '혀니의 리뷰톡톡', 'bloggerlink': 'blog.naver.com/hyuni2mail', 'postdate': '20240328'}, {'title': '포항카페 : 바르벳 효리단길(브런치메뉴.드립<b>커피</b>)', 'link': 'https://blog.naver.com/lovelyram2/223395703716', 'description': '브런치 메뉴도 보이고 <b>커피</b>와 음료종류도있었는데 금액이 착합니다 : ) 드립<b>커피</b> HOT 4.5 드립<b>커피</b> ICE 4.5 말차라떼 5.0 당근케이크 7.5 세명 온거 아님.. 둘이 온거임.. : ) ㅋㅋㅋ 원래 둘다 아아 시키는데 저는 이... ', 'bloggername': '○◑●동그람이의 여행로그●◐○', 'bloggerlink': 'blog.naver.com/lovelyram2', 'postdate': '20240326'}, {'title': '2024 코엑스 <b>커피</b>엑스포 사전예약 관람 후기', 'link': 'https://blog.naver.com/red9house/223397551040', 'description': '점심을 딤딤섬에서 맛나게 먹고 <b>커피</b>엑스포로 출동했어요. 2월에 사전등록 할인해서 1인당 2,000원에... <b>커피</b>엑스포는 <b>커피</b>산업 트렌드를 한눈에 볼 수 있고 <b>커피</b> 머신을 비롯한 각종 장비와 디저트까지... ', 'bloggername': '감사한 여유미님의 블로그', 'bloggerlink': 'blog.naver.com/red9house', 'postdate': '20240327'}, {'title': '광천동 브런치 카페 하우드<b>커피</b> 왕추천', 'link': 'https://blog.naver.com/perfect_aj/223397958328', 'description': '내가 넘나 좋아하는 동네 카페 하우드<b>커피</b>! 저번에 한번 왔다가 <b>커피</b>맛에 반하고, 디저트 맛에 또 반하고 친절한 사장님께 한번 더 반한 고런 동네 찐 맛집 카페 되시겠다! 오늘은 드뎌 하우드<b>커피</b>에서... ', 'bloggername': '애찡니블로그', 'bloggerlink': 'blog.naver.com/perfect_aj', 'postdate': '20240328'}, {'title': '후쿠오카 텐진 카페 <b>커피</b> 푸딩 맛집 킷사텐 코히샤노다', 'link': 'https://blog.naver.com/seul__look/223394511125', 'description': '킷사텐이예요 <b>커피</b> 푸딩으로 한국에서 유명세를 타고 있는 카페 그 외에도 다양한 디저트가 있어요.... 입고 <b>커피</b>를 내리는 모습이 멋져요 코히샤노다는 직원들 일하는 모습 촬영 불가예요. 그냥 본인 테이블... ', 'bloggername': 'I LIKE IT', 'bloggerlink': 'blog.naver.com/seul__look', 'postdate': '20240325'}, {'title': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두', 'link': 'https://blog.naver.com/hwain_ci/223393096187', 'description': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두 밖에서 <b>커피</b> 마시는 걸 좋아하긴 하지만 가성비가 떨어져서 보통 집에서 드립<b>커피</b> 방법을 이용해 마시고 있는데요 드립<b>커피</b> 내리는법이라고 해도 제... ', 'bloggername': '다이어트 레시피 만드는 이트샤', 'bloggerlink': 'blog.naver.com/hwain_ci', 'postdate': '20240324'}, {'title': '<b>커피</b>창업 성공을 위한 발판 마련하려면', 'link': 'https://blog.naver.com/kikiiyy/223394996784', 'description': '처음 <b>커피</b>창업을 고려하시는 분들이라면 사업 자체를 처음 시도해보는 경우가 많은데요. 자본이 충분한... 일반적으로 <b>커피</b>창업을 하게 되면 다양한 연령층의 고객을 만나게 됩니다. 10대부터 시작되는 젊은 세대... ', 'bloggername': 'CONDA', 'bloggerlink': 'blog.naver.com/kikiiyy', 'postdate': '20240325'}]}

# %%
json_data["items"]
# Out:
# [{'title': '핸드드립 맷돌<b>커피</b> 김해 삼계동카페 다반사',
#   'link': 'https://blog.naver.com/1004ykw/223395659112',
#   'description': '맷돌<b>커피</b>가 있다고 해서 궁금했다. 게다가 핸드드립임. 특색 있는 카페가 가까이에 있어서 가보았다.... 맷돌<b>커피</b>라는것도 이색적이지만, 핸드드립이라 오랜만에 구경했다. 핸드드립이 원두의 맛보다 물의 온도... ',
#   'bloggername': '너는 모르는 여자이야기',
#   'bloggerlink': 'blog.naver.com/1004ykw',
#   'postdate': '20240326'},
#  {'title': '수영, <b>커피</b>가 맛있는 조용한 카페 오우커 <b>커피</b> 바',
#   'link': 'https://blog.naver.com/pajamasis09/223397855270',
#   'description': '앞서 적은 광안리애에서 맛있는 식사 후 컨디션은 여전히 좋지 않았지만 식후 <b>커피</b>는 놓칠 수 없었기에!! 바로 근처 <b>커피</b>가 맛있다는 카페가 있어 큰 고민 없이 향했습니다 동네 특성상 작고 작은 가게들이... ',
#   'bloggername': 'EVERYDAY HAPPY SMILE ❤️',
#   'bloggerlink': 'blog.naver.com/pajamasis09',
#   'postdate': '20240328'},
#  {'title': '부천 시청역 슈퍼브<b>커피</b>로스터스 <b>커피</b> 맛집',
#   'link': 'https://blog.naver.com/kiti5447/223397966836',
#   'description': '부천 <b>커피</b> 맛집 테이크아웃<b>커피</b> 전문점 슈퍼브<b>커피</b>로스터스 안녕하세요. 류짱입니다. 벌써 한 주가 지나고 3월도 마지막 주가 되었는데요. 정말 3월에는 아이가 학교에 입학하고 나서 정신없이 시간이... ',
#   'bloggername': '류짱의 맛집 여행',
#   'bloggerlink': 'blog.naver.com/kiti5447',
#   'postdate': '20240328'},
#  {'title': '강릉 카페 이진리 / 시그니처 후추<b>커피</b> 대존맛',
#   'link': 'https://blog.naver.com/hyuni2mail/223397084072',
#   'description': '중에서 <b>커피</b>가 맛있는 곳, 특히 시그니처인 후추<b>커피</b>가 맛있는 카페인 강릉 이진리 카페를 찾아갔어요 :) 요즘 떠오르는 강릉 맛집이라는 감자유원지 후기가 궁금하시다면 위 링크 클릭해서 같이 보셔도... ',
#   'bloggername': '혀니의 리뷰톡톡',
#   'bloggerlink': 'blog.naver.com/hyuni2mail',
#   'postdate': '20240328'},
#  {'title': '포항카페 : 바르벳 효리단길(브런치메뉴.드립<b>커피</b>)',
#   'link': 'https://blog.naver.com/lovelyram2/223395703716',
#   'description': '브런치 메뉴도 보이고 <b>커피</b>와 음료종류도있었는데 금액이 착합니다 : ) 드립<b>커피</b> HOT 4.5 드립<b>커피</b> ICE 4.5 말차라떼 5.0 당근케이크 7.5 세명 온거 아님.. 둘이 온거임.. : ) ㅋㅋㅋ 원래 둘다 아아 시키는데 저는 이... ',
#   'bloggername': '○◑●동그람이의 여행로그●◐○',
#   'bloggerlink': 'blog.naver.com/lovelyram2',
#   'postdate': '20240326'},
#  {'title': '2024 코엑스 <b>커피</b>엑스포 사전예약 관람 후기',
#   'link': 'https://blog.naver.com/red9house/223397551040',
#   'description': '점심을 딤딤섬에서 맛나게 먹고 <b>커피</b>엑스포로 출동했어요. 2월에 사전등록 할인해서 1인당 2,000원에... <b>커피</b>엑스포는 <b>커피</b>산업 트렌드를 한눈에 볼 수 있고 <b>커피</b> 머신을 비롯한 각종 장비와 디저트까지... ',
#   'bloggername': '감사한 여유미님의 블로그',
#   'bloggerlink': 'blog.naver.com/red9house',
#   'postdate': '20240327'},
#  {'title': '광천동 브런치 카페 하우드<b>커피</b> 왕추천',
#   'link': 'https://blog.naver.com/perfect_aj/223397958328',
#   'description': '내가 넘나 좋아하는 동네 카페 하우드<b>커피</b>! 저번에 한번 왔다가 <b>커피</b>맛에 반하고, 디저트 맛에 또 반하고 친절한 사장님께 한번 더 반한 고런 동네 찐 맛집 카페 되시겠다! 오늘은 드뎌 하우드<b>커피</b>에서... ',
#   'bloggername': '애찡니블로그',
#   'bloggerlink': 'blog.naver.com/perfect_aj',
#   'postdate': '20240328'},
#  {'title': '후쿠오카 텐진 카페 <b>커피</b> 푸딩 맛집 킷사텐 코히샤노다',
#   'link': 'https://blog.naver.com/seul__look/223394511125',
#   'description': '킷사텐이예요 <b>커피</b> 푸딩으로 한국에서 유명세를 타고 있는 카페 그 외에도 다양한 디저트가 있어요.... 입고 <b>커피</b>를 내리는 모습이 멋져요 코히샤노다는 직원들 일하는 모습 촬영 불가예요. 그냥 본인 테이블... ',
#   'bloggername': 'I LIKE IT',
#   'bloggerlink': 'blog.naver.com/seul__look',
#   'postdate': '20240325'},
#  {'title': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두',
#   'link': 'https://blog.naver.com/hwain_ci/223393096187',
#   'description': '드립<b>커피</b> 방법 내리는법 과테말라 스페셜티 원두 밖에서 <b>커피</b> 마시는 걸 좋아하긴 하지만 가성비가 떨어져서 보통 집에서 드립<b>커피</b> 방법을 이용해 마시고 있는데요 드립<b>커피</b> 내리는법이라고 해도 제... ',
#   'bloggername': '다이어트 레시피 만드는 이트샤',
#   'bloggerlink': 'blog.naver.com/hwain_ci',
#   'postdate': '20240324'},
#  {'title': '<b>커피</b>창업 성공을 위한 발판 마련하려면',
#   'link': 'https://blog.naver.com/kikiiyy/223394996784',
#   'description': '처음 <b>커피</b>창업을 고려하시는 분들이라면 사업 자체를 처음 시도해보는 경우가 많은데요. 자본이 충분한... 일반적으로 <b>커피</b>창업을 하게 되면 다양한 연령층의 고객을 만나게 됩니다. 10대부터 시작되는 젊은 세대... ',
#   'bloggername': 'CONDA',
#   'bloggerlink': 'blog.naver.com/kikiiyy',
#   'postdate': '20240325'}]
