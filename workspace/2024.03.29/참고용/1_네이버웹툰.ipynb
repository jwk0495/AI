# %%
# !pip install -qq selenium webdriver_manager

# %%
# 1. 모듈 임포트
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# %%
# 2. 드라이버 옵션 설정
chrom_options = webdriver.ChromeOptions()
chrom_options.add_experimental_option('detach', True)
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), 
                          options=chrom_options)

# %%
# 3. 브라우저 띄우기
url = 'https://comic.naver.com/webtoon'
driver.get(url)
time.sleep(2)

# %%
# 4. 별점 순으로 이동
css_select = "#container > div.component_wrap.type2 > div.ComponentHead__component_head--O2tPr > div > div > button:nth-child(4)"
driver.find_element(By.CSS_SELECTOR, css_select).click()
time.sleep(1)

# %%
# 5. html 요소 추출
# 5.1 요일별 데이터 추출
webtoon_list = driver.find_elements(By.CSS_SELECTOR, 'ul.WeekdayMainView__daily_list--R52q0')
webtoon_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13427")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13428")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13429")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.1072")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.1069")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.1067")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13430")>]

# %%
print(len(webtoon_list)) # 일주일 7일. 월요일부터 시작
# Out:
# 7

# %%
# 5.2 수요일 데이터 추출
wed_data = webtoon_list[2] # 수요일 데이터
print(wed_data.text)
# Out:
# UP
# 오, 친애하는 숙적
# UP
# 썩은 핑크의 법칙
# 휴재
# 3X3!
# UP
# 마왕까지 한 걸음
# UP
# 뮤즈 온 유명
# UP
# 내향남녀
# UP
# 재벌집 막내아들
# UP
# 일립예고 학생들
# UP
# 마법사랑해
# UP
# 당신의 그림자를 그만두었을 때
# UP
# 오만의 시대
# UP
# 버려진 나의 최애를 위하여
# UP
# 할배무사와 지존 손녀
# UP
# 불편한 관계
# UP
# 루루라라 우리네 인생
# UP
# 꽃만 키우는데 너무강함
# UP
# 사내연애 사절!
# UP
# 비서 일탈
# UP
# 이러면 안 돼요, 전하!
# UP
# 그 악룡은 무엇을 위해 사는가
# UP
# 만물의 영장
# UP
# 네이처맨
# 신작
# 청유물
# UP
# 순결을 그대에게
# 청유물
# UP
# 남편을 죽여줘요
# UP
# 선천적 얼간이들
# UP
# 황제사냥
# UP
# 게임 속 바바리안으로 살아남기
# UP
# 내가 사랑한 물고기
# UP
# 보물과 괴물의 도시
# UP
# 정글쥬스
# UP
# 사랑하는 여배우들
# 휴재
# 사기 친 공작님을 유혹해버렸다
# UP
# 흔한햄
# UP
# 영광의 해일로
# UP
# 가족같은 XX
# UP
# 아인슈페너
# UP
# 나 혼자 네크로맨서
# UP
# 보스였음
# 청유물
# UP
# 앞집나리
# UP
# 두 번째 딸로 태어났습니다
# UP
# 순수한 동거생활
# UP
# 서울밤피어
# UP
# 학생만 하면 안 될까요?
# UP
# 더티드레스
# UP
# 천마육성
# UP
# 베니루 BAENIRU
# UP
# 마도귀환록
# UP
# SPT - 박쥐의 시간
# UP
# 게임 최강 트롤러
# UP
# 촉법소년
# UP
# 여친을 찾아서
# UP
# 나노마신
# UP
# 쌍둥이 영애가 남장을 하는 이유
# UP
# 코인 리벤지
# UP
# 너와 XX
# UP
# 트롤트랩
# UP
# 갓트
# 신작
# UP
# 첫날밤을 보낸 그 악녀를 찾습니다
# UP
# 올빼미와 여름 하늘
# UP
# VS
# UP
# 현실퀘스트
# UP
# 회귀한 천재 헌터의 슬기로운 청소생활
# UP
# 배트맨: 웨인 패밀리 어드벤처
# UP
# 카루나
# UP
# 나의 불편한 상사
# UP
# 미리보기
# UP
# 첫사랑, 두 번째
# UP
# 권리행사자
# UP
# 웨폰 크리에이터
# 신작
# UP
# 개구리 인간
# UP
# 관계중독
# UP
# 시한부 천재 암흑기사
# 휴재
# 킬더킹
# UP
# 규격 외 혈통 천재
# UP
# 맛집
# UP
# 최강전설 강해효
# UP
# 35cm
# UP
# 일진만화에서 살아남기
# UP
# 미라주
# UP
# 유월의 소한
# UP
# 괴물의 바다
# UP
# 나쁜 마법사의 꿈
# UP
# 2차전직 스킵용사
# UP
# 돈내놔
# UP
# 따개비
# UP
# 잘못된 연애
# UP
# 히든클래스 중력자로 최강을 노린다
# UP
# 이상한 변호사 우영우

# %%
wed_list = wed_data.find_elements(By.CLASS_NAME, "ContentTitle__title--e3qXt")
print(len(wed_list))
# Out:
# 93

# %%
thirdy = webtoon_list[3]
titles = thirdy.find_elements(By.CLASS_NAME, "ContentTitle__title--e3qXt")
titles
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13699")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13757")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13758")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13759")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.13760")>,
#  <selenium.webdriver.remote.webelement.WebElement (session
>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8414")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8398")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8382")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8366")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8350")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8334")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f978b20304c688aba622ecdd71efb158", element="f.BE1300D49C6C4B710B4EA501B10472D0.d.401743A4CADA8E5788C6FD4E16E3CFB4.e.8318")>]

# %%
for i in titles:
    print(i.text)
# Out:
# 오, 친애하는 숙적
# 썩은 핑크의 법칙
# 3X3!
# 마왕까지 한 걸음
# 뮤즈 온 유명
# 내향남녀
# 재벌집 막내아들
# 일립예고 학생들
# 마법사랑해
# 당신의 그림자를 그만두었을 때
# 오만의 시대
# 버려진 나의 최애를 위하여
# 할배무사와 지존 손녀
# 불편한 관계
# 루루라라 우리네 인생
# 꽃만 키우는데 너무강함
# 사내연애 사절!
# 비서 일탈
# 이러면 안 돼요, 전하!
# 그 악룡은 무엇을 위해 사는가
# 만물의 영장
# 네이처맨
# 순결을 그대에게
# 남편을 죽여줘요
# 선천적 얼간이들
# 황제사냥
# 게임 속 바바리안으로 살아남기
# 내가 사랑한 물고기
# 보물과 괴물의 도시
# 정글쥬스
# 사랑하는 여배우들
# 사기 친 공작님을 유혹해버렸다
# 흔한햄
# 영광의 해일로
# 가족같은 XX
# 아인슈페너
# 나 혼자 네크로맨서
# 보스였음
# 앞집나리
# 두 번째 딸로 태어났습니다
# 순수한 동거생활
# 서울밤피어
# 학생만 하면 안 될까요?
# 더티드레스
# 천마육성
# 베니루 BAENIRU
# 마도귀환록
# SPT - 박쥐의 시간
# 게임 최강 트롤러
# 촉법소년
# 여친을 찾아서
# 나노마신
# 쌍둥이 영애가 남장을 하는 이유
# 코인 리벤지
# 너와 XX
# 트롤트랩
# 갓트
# 첫날밤을 보낸 그 악녀를 찾습니다
# 올빼미와 여름 하늘
# VS
# 현실퀘스트
# 회귀한 천재 헌터의 슬기로운 청소생활
# 배트맨: 웨인 패밀리 어드벤처
# 카루나
# 나의 불편한 상사
# 미리보기
# 첫사랑, 두 번째
# 권리행사자
# 웨폰 크리에이터
# 개구리 인간
# 관계중독
# 시한부 천재 암흑기사
# 킬더킹
# 규격 외 혈통 천재
# 맛집
# 최강전설 강해효
# 35cm
# 일진만화에서 살아남기
# 미라주
# 유월의 소한
# 괴물의 바다
# 나쁜 마법사의 꿈
# 2차전직 스킵용사
# 돈내놔
# 따개비
# 잘못된 연애
# 히든클래스 중력자로 최강을 노린다
# 이상한 변호사 우영우

# %%
# 6. 타이틀을 결과로 저장하기
result_data = []
for item in wed_list:
    result_data.append(item.text)
result_data
# Out:
# ['산타 스카우트',
#  '진돌히디만화',
#  '미래의 골동품 가게',
#  '에브리띵 이즈 파인',
#  '남사친의 법칙',
#  '쓰레기는 쓰레기통에!',
#  '용한소녀',
#  '베이비 폭군',
#  '어린이집 다니는 구나',
#  '마른 가지에 바람처럼',
#  '겨울 정원의 하와르',
#  '나의 신은 욕망꾸러기',
#  '범상찮은 밤',
#  '안녕, 나의 수집',
#  '두 마리를 위한 뜰',
#  '조조코믹스',
#  '강아지는 멍멍하고 짖지 않아!',
#  '인과관계',
#  '별을 품은 소드마스터',
#  '마음의소리(였던 것)',
#  '흔한 빙의물인 줄 알았다',
#  '어느 백작 영애의 이중생활',
#  '하렘의 남자들',
#  '좀간',
#  '어느 마법사의 식당',
#  '망치하르방',
#  '수인 보호소에서 남주를 입양해 버렸다',
#  '로어 올림푸스',
#  '반짝반짝 작은 눈',
#  '중간에서 만나',
#  '말숙이를 부탁해',
#  '전지적 독자 시점',
#  '울어 봐, 빌어도 좋고',
#  '귀비나리',
#  '66666년 만에 환생한 흑마법사',
#  '황후를 훔친 이는 누구인가',
#  '무림서부',
#  '더 베이비시터',
#  '악의 등교',
#  '영웅&마왕&악당',
#  '미시령',
#  '연애일기',
#  '두 번 사는 프로듀서',
#  '49번 남았습니다, 스승님!',
#  '그 남자의 은밀한 하루',
#  '화산귀환',
#  '운명을 보는 회사원',
#  '칼에 취한 밤을 걷다',
#  '수플레 팬 케이크',
#  '언덕 위의 제임스',
#  '칼부림',
#  '사상최강',
#  '누가 나를 죽였을까',
#  '짝사랑은 결혼으로 끝나지 않는다',
#  '고백하면 끝나는 만화',
#  '수요웹툰의 나강림',
#  '그때 그 채영민',
#  '나랑 해요',
#  '이런 미친 엔딩',
#  '무직백수 계백순',
#  '낙원의 이론',
#  '어린 상사',
#  '나의 계절',
#  '백XX',
#  '히어로 더 맥시멈',
#  '판타지 여동생!',
#  '신입은 낮져밤이',
#  '일렉시드',
#  '연애고수',
#  '튜토리얼 탑의 고인물',
#  '나를 낳아줘',
#  '사랑아, 영원해!',
#  '급식아빠',
#  '괴물공작의 딸',
#  '변방의 외노자',
#  '강철을 먹는 플레이어',
#  '왕따가 격투기를 너무 잘함',
#  '두꺼비집',
#  '솔그린',
#  '우리의 연애일지',
#  '나쁜사람',
#  '뽀대작렬',
#  '결혼 시뮬레이션',
#  '기묘한 만화',
#  '선배는 나빠요!',
#  '돌아온 쿠쿠짱',
#  '1등급 싸움과외',
#  '격기3반',
#  '멸종위기종인간',
#  '닥터앤닥터 병원일기',
#  '사생돌',
#  '헬퍼 2 : 킬베로스',
#  '마님이네 미국 시골집 이야기']

# %%
# 실습
