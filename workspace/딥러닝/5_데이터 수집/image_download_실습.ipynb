# %%
# !pip install bing-image-downloader

# %%
# 1.데이터 수집
from bing_image_downloader import downloader

# %%
query = "차은우"
downloader.download(query=query, limit=200,
                    output_dir="../data/resnet_data",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\차은우
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.newsculture.press/news/photo/202209/510612_620904_3732.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-jmtpSrQDvA4/W22zaZu_ugI/AAAAAAAAAFY/2UaMtvxQXmUNE2GEVPqPLUEn5rXp5x3hgCLcBGAs/s1600/KakaoTalk_Moim_4BT8Folfwlsr1QUqMILa2lDZh4vuYq.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.hankyung.com/photo/202210/BF.31585475.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://image.ytn.co.kr/osen/2022/11/f83030de-f4fc-4610-9611-77a69bfd3be5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://img.asiatoday.co.kr/file/2017y/04m/19d/2017041901001776700125191.jpg?1
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://image.kmib.co.kr/online_image/2020/0518/611811110014591003_1.jpg
# ...

# %%
query = "카리나"
downloader.download(query=query, limit=200,
                    output_dir="../data/resnet_data",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\카리나
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2022/07/15/1746f522-fd6d-4201-9e4b-d89c50b0bce4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://image.ytn.co.kr/general/jpg/2021/0924/202109240922165182_d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://1.bp.blogspot.com/-wgUQjSbZ3LQ/YJCl9WSTlXI/AAAAAAAAvQk/9CCRPWxYrdsnkhRrZDba0ZLGUBgrBUZHgCLcBGAsYHQ/s0/ggoorr.net_002.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/02/9c8a4064-6ae8-4c8e-b09f-010e112ad6e1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn.onepicknews.co.kr/news/photo/202304/4459_9286_554.jpg
# [%] File Downloaded !
#
# ...

# %%
query = "마동석"
downloader.download(query=query, limit=200,
                    output_dir="../data/resnet_data",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\마동석
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/26/bbe2deec-47db-4866-a8ce-abb39a0a181d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/26/68c2d7a2-2306-4cb6-8602-bc8783572906.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2022/05/22/802a7b06-bfa3-429d-b8b0-f5a2628bb46d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.newscribe.kr/news/photo/202304/560_6050_4827.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://yt3.ggpht.com/a/AATXAJzToiindt46nVDuUItLGCYJRTvPYYj3804WHIr_ug=s900-c-k-c0xffffffff-no-rj-mo
# [%] File Downloaded !
#
# ...

# %%
query = "오타니"
downloader.download(query=query, limit=200,
                    output_dir="../data/resnet_data",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\오타니
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img.hani.co.kr/imgdb/resize/2017/0428/00503161_20170428.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.hankyung.com/photo/202107/PAP20210714112801055_P4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://t1.daumcdn.net/news/201804/25/NEWS1/20180425141901607ivce.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img6.yna.co.kr/mpic/YH/2021/07/03/MYH20210703003900038.jpg
# [!] Issue getting: https://img6.yna.co.kr/mpic/YH/2021/07/03/MYH20210703003900038.jpg
# [!] Error:: <urlopen error [SSL: UNSAFE_LEGACY_RENEGOTIATION_DISABLED] unsafe legacy renegotiation disabled (_ssl.c:1000)>
# [%] Downloading Image #4 from https://flexible.img.hani.co.kr/flexible/normal/970/646/imgdb/original/2021/1119/20211119500933.jpg
# [%] File Downloaded !
#
# ...
