# %%
# !pip install bing-image-downloader

# %%
# 1.데이터 수집
from bing_image_downloader import downloader

# %%
query = "마동석"
downloader.download(query=query, limit=40,
                    output_dir="../data/resnet_data",
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\마동석
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/26/bbe2deec-47db-4866-a8ce-abb39a0a181d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.sbs.co.kr/newsnet/etv/upload/2022/10/20/30000798339_1280.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://entertainimg.kbsmedia.co.kr/cms/uploads/BBSIMAGE_20210629092000_3e790d5da1a202a9c397abb508245706.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://img.etoday.co.kr/pto_db/2018/10/600/20181023114442_1262184_664_866.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://img3.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/201710/09/newsen/20171009060319392cebw.jpg
# [%] File Downloaded !
#
# ...
