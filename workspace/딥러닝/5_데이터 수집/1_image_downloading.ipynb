# %%
# !pip install bing-image-downloader

# %% [markdown]
# ### 1. 데이터 수집하기

# %%
from bing_image_downloader import downloader
query = '카리나'
downloader.download(query, limit=100,
                    output_dir='../data/resnet_data',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\카리나
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2022/07/15/1746f522-fd6d-4201-9e4b-d89c50b0bce4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://image.ytn.co.kr/general/jpg/2021/0924/202109240922165182_d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://1.bp.blogspot.com/-wgUQjSbZ3LQ/YJCl9WSTlXI/AAAAAAAAvQk/9CCRPWxYrdsnkhRrZDba0ZLGUBgrBUZHgCLcBGAsYHQ/s0/ggoorr.net_002.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/02/9c8a4064-6ae8-4c8e-b09f-010e112ad6e1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://cdn.onepicknews.co.kr/news/photo/202304/4459_9286_554.jpg
# [%] File Downloaded !
#
# ...

# %%
query = '차은우'
downloader.download(query, limit=100,
                    output_dir='../data/resnet_data',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\차은우
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.newsculture.press/news/photo/202209/510612_620904_3732.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-jmtpSrQDvA4/W22zaZu_ugI/AAAAAAAAAFY/2UaMtvxQXmUNE2GEVPqPLUEn5rXp5x3hgCLcBGAs/s1600/KakaoTalk_Moim_4BT8Folfwlsr1QUqMILa2lDZh4vuYq.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.hankyung.com/photo/202210/BF.31585475.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://image.ytn.co.kr/osen/2022/11/f83030de-f4fc-4610-9611-77a69bfd3be5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://img.asiatoday.co.kr/file/2017y/04m/19d/2017041901001776700125191.jpg?1
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://image.kmib.co.kr/online_image/2020/0518/611811110014591003_1.jpg
# ...

# %%
query = '마동석'
downloader.download(query, limit=100,
                    output_dir='../data/resnet_data',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\마동석
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://talkimg.imbc.com/TVianUpload/tvian/TViews/image/2021/07/26/bbe2deec-47db-4866-a8ce-abb39a0a181d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://img.hankyung.com/photo/201709/01.14677695.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://img.hankyung.com/photo/201811/03.18208318.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://img.tf.co.kr/article/home/2018/11/29/201842251543458308.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.allkpop.com/upload/2021/02/content/061202/1612630940-20210206-madongsuk.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://img.hankyung.com/photo/202205/BF.30060884.1.jpg
# [%] File Downloaded !
#
# ...

# %%
query = '박보영'
downloader.download(query, limit=100,
                    output_dir='../data/resnet_data',
                    adult_filter_off=True,
                    force_replace=False,
                    timeout=60
                    )
# Out:
# [%] Downloading Images to d:\AI\AI\workspace\딥러닝\5_데이터 수집\..\data\resnet_data\박보영
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://img.hankyung.com/photo/202308/BF.34129649.1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.newsculture.press/news/photo/202308/529759_657603_4037.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://1.bp.blogspot.com/-Xnwo16OZRKA/YFBDX8ypp0I/AAAAAAAA66Q/PjI6yVwEUSwhDvCnFwGzddy20cBaoTaTgCNcBGAsYHQ/s0/15.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://1.bp.blogspot.com/-z-59Y8sKj7c/YFBDUf5vlgI/AAAAAAAA65o/W4W5YayvqTYRQ6zLUDU_nfLrRMeaIIPfgCNcBGAsYHQ/s0/07.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://archivenew.vop.co.kr/images/78ddf9ac628c0853877cd0d4af0d3eeb/2020-01/marked/09112949_44.jpg
# [%] File Downloaded !
#
# ...
