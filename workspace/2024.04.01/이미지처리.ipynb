# %% [markdown]
# ### 설치 확인

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.9.0

# %% [markdown]
# ### 이미지 읽어오기 및 정보 출력

# %%
img = cv2.imread("example_img1.png") # Alpha채널 없을 수 있음
img
# Out:
# array([[[109,  22,   6],
#         [130,  50,  27],
#         [164,  93,  60],
#         ...,
#         [141, 248, 252],
#         [110, 228, 229],
#         [ 94, 217, 215]],
#
#        [[149,  66,  45],
#         [136,  57,  30],
#         [162,  91,  54],
#         ...,
#         [ 79, 183, 188],
#         [132, 245, 248],
#         [115, 235, 235]],
#
#        [[132,  57,  25],
#         [118,  44,   8],
#         [195, 120,  76],
#         ...,
#         [ 90, 188, 194],
#         [124, 230, 237],
#         [143, 254, 255]],
#
#        ...,
#
#        [[ 35,  18,  45],
#         [ 36,  20,  44],
#         [ 35,  20,  41],
#         ...,
#         [ 37,  26,  34],
#         [ 42,  30,  36],
#         [ 38,  26,  32]],
#
#        [[ 45,  33,  53],
#         [ 41,  29,  47],
#         [ 38,  26,  44],
#         ...,
#         [ 35,  24,  32],
#         [ 40,  28,  34],
#         [ 40,  26,  32]],
#
#        [[ 47,  37,  53],
#         [ 39,  29,  45],
#         [ 36,  24,  42],
# ...

# %%
## 이미지 정보
print(img.shape)    # 세로, 가로, 채널 명
print(img.dtype)    # 이미지 타입
print(img.ndim)     # 차원 수
print(img.size)     # 이미지 크기

print(img.min())    
print(img.max())    # 0~255 --> 0 ~ 1 바꾼 이미지
# Out:
# (640, 1024, 3)
# uint8
# 3
# 1966080
# 0
# 255

# %% [markdown]
# ### 이미지 출력

# %%
cv2.imshow("basic image", img)   # cv2 에서 한글 이름 경로 안됨 ㅠㅠ
cv2.waitKey(0)                   # 꼭 넣어줘야 됨
cv2.destroyAllWindows()          # 아무 키 누르면 닫힘

# %% [markdown]
# ### 이미지 출력 -- matplotlib 로 출력

# %%
import matplotlib.pyplot as plt
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# plt.imshow("gray image", img_gray)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
plt.imshow(img_gray, cmap = "gray")
plt.show()

# %% [markdown]
# ### 3. 이미지 저장

# %%
cv2.imwrite("new_image_gray.jpg", img_gray)
# Out:
# True

# %% [markdown]
# ### 4-1. 픽셀 값에 접근 및 변경해보기

# %%
duck_img = cv2.imread("duck1.jpg")
duck_img_rgb = cv2.cvtColor(duck_img, cv2.COLOR_BGR2RGB)
plt.imshow(duck_img_rgb)
plt.show()

# %% [markdown]
# ##픽셀로 자르기

# %%
duck_img = cv2.imread("duck1.jpg")
duck_img_rgb = cv2.cvtColor(duck_img, cv2.COLOR_BGR2RGB)
new_duck = duck_img_rgb[200:800, 200:800]               # 픽셀 자르기
plt.imshow(new_duck)
plt.show()

# %%
b, g, r = cv2.split(img)
b = b+50
img_merged = cv2.merge([b, g, r])
cv2.imshow("img_mefged", img_merged)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
img_merged_rgb = cv2.cvtColor(img_merged, cv2.COLOR_BGR2RGB)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(7, 5))
plt.subplot(1,2,1)
plt.title("original_img")
plt.imshow(img_rgb)
plt.axis('off')

plt.subplot(1,2,2)
plt.title("original_img")
plt.imshow(img_merged_rgb)
plt.axis('off')

plt.show()

# %% [markdown]
# ### 6-2. 이미지 크기 조정

# %%
resized_img = cv2.resize(origin_img, (0,0), fx = 0.5, fy=0.5)
resized_img_rgb = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(7,5))
plt.title("resized_img")
plt.imshow(resized_img_rgb)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 resized_img = cv2.resize(origin_img, (0,0), fx = 0.5, fy=0.5)
#       2 resized_img_rgb = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
#       3 plt.figure(figsize=(7,5))
#
# NameError: name 'origin_img' is not defined

# %% [markdown]
# ### 6-3. 이미지 회전

# %%
center = (origin_img.shape[0]//2, origin_img.shape[1]//2)
print(center)
rotation_matrix_45 = cv2.getRotationMatrix2D(center, 45, ) 
rotation_matrix_45 = cv2.warpAffine(origin_img, rotation_matrix_45, (origin_img.shape[1],origin_img.shpae[0]))

resized_img_rgb = cv2.cvtColor(resized_img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(7,5))
plt.title("resized_img")
plt.imshow(resized_img_rgb)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 print(origin_img.shape)
#
# NameError: name 'origin_img' is not defined

# %% [markdown]
# ### 6-4. 이미지 뒤집기

# %% [markdown]
# ### 7. 마스크 이미지 적용

# %%
## 마스크 이미지 하나 가져오기
mask_img = cv2.imread("mask_heart.jpg")
print(mask_img.shape)
masked_img = cv2.bitwise_and(origin_img, origin_img, mask = mask_img)

img_rgb = cv2.cvtColor(masked_img, cv2.COLRO_BGR2RGB)
plt.figure(figsize=(7,5))
plt.title("resized_img")
plt.imshow(resized_img_rgb)

plt.show()
# Out:
# (640, 1024, 3)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       2 mask_img = cv2.imread("mask_heart.jpg")
#       3 print(mask_img.shape)
# ----> 4 masked_img = cv2.bitwise_and(origin_img, origin_img, mask = mask_img)
#       6 img_rgb = cv2.cvtColor(masked_img, cv2.COLRO_BGR2RGB)
#       7 plt.figure(figsize=(7,5))
#
# NameError: name 'origin_img' is not defined
